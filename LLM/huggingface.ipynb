# %% [markdown]
# ## Deepseek-R1 LLM

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "deepseek-ai/DeepSeek-R1:novita"
})

print(response)
# Out:
# {'id': 'c9b64cf5e0282576e6f1fc9bf023675e', 'object': 'chat.completion', 'created': 1783627026, 'model': 'deepseek/deepseek-r1-turbo', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '<think>\nOkay, the user asked, "What is the capital of France?" That seems straightforward. Let me recall the basic geography fact—Paris is the capital. But wait, why would someone ask this? Maybe they\'re a student doing homework, a traveler planning a trip, or just confirming a fact they heard.  \n\nHmm, the question is simple, but I should make sure my answer is clear and helpful. Adding a bit more context could be useful—like mentioning France\'s status as a republic or that Paris is a major cultural hub. That way, it’s not just a one-word answer.  \n\nAlso, the user didn’t specify needing more details, but offering additional info politely ("if you\'d like to know more...") keeps it open-ended. They might actually be curious about landmarks or history but didn’t ask yet.  \n\nNo need to overcomplicate it, though. Just answer directly, then gently extend the conversation. Keep it friendly and precise!\n</think>\nThe capital of France is **Paris**.  \n\nParis is not only the political center of France but also its largest city and a global hub for art, fashion, gastronomy, and culture. It\'s home to iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral.  \n\nFrance operates as a unitary semi-presidential republic, with Paris serving as the seat of its government, including the Presidential Élysée Palace and the French Parliament.  \n\nIf you\'d like to know more about Paris\'s history, significance, or attractions, feel free to ask! 😊'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 10, 'completion_tokens': 322, 'total_tokens': 332, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'text_tokens': 0, 'image_tokens': 0, 'video_tokens': 0}, 'completion_tokens_details': None}, 'system_fingerprint': ''}

# %%
print(response["choices"][0]['message']['content'])
# Out:
# <think>
# Okay, the user asked, "What is the capital of France?" That seems straightforward. Let me recall the basic geography fact. Paris is definitely the capital. But why stop there? Maybe they need more context.
#
# Hmm, could this be a test question? Or perhaps someone new to geography? Either way, adding a bit more info might help. I should mention that Paris is also France's largest city and its political/cultural hub.
#
# Wait—should I check if there's any trick here? Like, historical capitals? No, Versailles was temporary, but Paris has been the capital for centuries. No need to overcomplicate it.
#
# The user didn't specify depth, so I'll keep it concise but include key roles: government seat, cultural significance, landmarks. That covers bases without overwhelming.
#
# Finally, end on a friendly note—offer more help if needed. Simple, clear, and helpful.
# </think>
# The capital of France is **Paris**.
#
# Paris is not only the political center of France (housing the President, Parliament, and government institutions) but also its largest city and a global hub for culture, art, fashion, gastronomy, and history. Iconic landmarks like the Eiffel Tower, Louvre Museum, and Notre-Dame Cathedral are located there.
#
# Let me know if you'd like more details! 😊

# %% [markdown]
# ## Meta Llama LLM

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "meta-llama/Llama-3.1-8B-Instruct:novita"
})

print(response)
# Out:
# {'id': 'e88f1d75b110758723c05ae8997f711c', 'object': 'chat.completion', 'created': 1783526924, 'model': 'meta-llama/llama-3.1-8b-instruct', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'The capital of France is Paris.'}, 'finish_reason': 'stop', 'content_filter_results': {'hate': {'filtered': False}, 'self_harm': {'filtered': False}, 'sexual': {'filtered': False}, 'violence': {'filtered': False}, 'jailbreak': {'filtered': False, 'detected': False}, 'profanity': {'filtered': False, 'detected': False}}}], 'usage': {'prompt_tokens': 42, 'completion_tokens': 8, 'total_tokens': 50, 'prompt_tokens_details': None, 'completion_tokens_details': None}, 'system_fingerprint': ''}

# %%
print(response["choices"][0]["message"]['content'])
# Out:
# The capital of France is Paris.

# %% [markdown]
# ## DeepSeek-V4-Pro LLM

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "deepseek-ai/DeepSeek-V4-Pro:novita"
})

print(response["choices"][0]["message"]['content'])
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ## zai-org/GLM-5.2 LLM

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "zai-org/GLM-5.2:novita"
})

print(response["choices"][0]["message"]['content'])
# Out:
# The capital of France is Paris.

# %% [markdown]
# ## Qwen3-Coder-Next LLM

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "Qwen/Qwen3-Coder-Next:novita"
})

print(response["choices"][0]["message"]['content'])
# Out:
# The capital of France is Paris. 🇫🇷

# %% [markdown]
# ## openai/gpt-oss-20b LLM

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ],
    "model": "openai/gpt-oss-20b:groq"
})

print(response["choices"][0]["message"]['content'])
# Out:
# The capital of France is Paris.
