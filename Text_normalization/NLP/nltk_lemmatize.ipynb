# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger') #this will help in finding word belongs to which pos
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91789\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\91789\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\91789\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tokens = ['running', 'jumps', 'children', 'better', 'geese', 'cars', 'wolves', 'going', 'ate', 'happier', 'feet', 'houses']
tokens
# Out:
# ['running',
#  'jumps',
#  'children',
#  'better',
#  'geese',
#  'cars',
#  'wolves',
#  'going',
#  'ate',
#  'happier',
#  'feet',
#  'houses']

# %%
lemmatizer=WordNetLemmatizer()

# %%
for word in tokens:
    print(word,'--->',lemmatizer.lemmatize(word,pos='v'))
# Out:
# running ---> run
# jumps ---> jump
# children ---> children
# better ---> better
# geese ---> geese
# cars ---> cars
# wolves ---> wolves
# going ---> go
# ate ---> eat
# happier ---> happier
# feet ---> feet
# houses ---> house

# %% [markdown]
# ### Lemmatizer
# - here every word is not being lemmatize because here by default it is using noun
# - so here it uses lemmatize method only when words are noun
# - here we also need to change the pos tag accordingly how and which type of words are present which is not possible to check manually thats the disadvantage in lemmatization, this we can overcome in spaCy Lemmatize

# %% [markdown]
# ### Difference between stemming and lemmatize
# - Stemming works based on set of rules, directly removes the suffix wont check that if a word is noun or pronoun etc
# - Lemmatize works based on pos(parts of speech) tag, suppose if we mention as pos='noun' then it will check is the word noun if it is noun then it applies lemmatization for that word

# %% [markdown]
# ***The Part Of Speech tag. Valid options are "n" for nouns, "v" for verbs, "a" for adjectives, "r" for adverbs and "s" for satellite adjectives.***

# %%
updated_tokens=nltk.pos_tag(tokens)

# %%
''' 
nltk.pos_tag(tokens)
N - 'n' 
V - 'v'
JJ - 'a'(adjectives)
R - 'r'(adverb)
'n'
'''
# Out:
# " \nnltk.pos_tag(tokens)\nN - 'n' \nV - 'v'\nJJ - 'a'(adjectives)\nR - 'r'(adverb)\n'n'\n"

# %%
def find_postag(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('R'):
        return 'r'
    else:
        return 'n'

# %%
for word,tag in updated_tokens:
    # print(word,find_postag(tag))
    # print(word,'--->',lemmatizer.lemmatize(word,pos=find_postag(tag)))
    tagged_words=lemmatizer.lemmatize(word, find_postag(tag))
    print(tagged_words)
# Out:
# run
# jump
# child
# well
# geese
# car
# wolves
# go
# ate
# happy
# foot
# house

# %% [markdown]
# - in nltk we require stemming and lemmatize to convert the word to its root form
