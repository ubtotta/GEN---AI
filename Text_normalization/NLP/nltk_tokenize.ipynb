# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91789\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\91789\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
words_tokens=word_tokenize('hellO I aM UdAya KumAr')

# %%
words_tokens
# Out:
# ['hellO', 'I', 'aM', 'UdAya', 'KumAr']

# %%
sent_tokens=sent_tokenize('Hello i am udaya kumar I am currenlty doing the intership at Pyspiders in the domain of Python with Data Science in BTM layout')

# %%
sent_tokens
# Out:
# ['Hello i am udaya kumar I am currenlty doing the intership at Pyspiders in the domain of Python with Data Science in BTM layout']
