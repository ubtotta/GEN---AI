# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
res='''Hello i am udaya kumar\n. 
      I am currenlty doing the intership at Pyspiders in the domain of Python with Data Science. Located BTM layout.'''

# %%
words_tokens=word_tokenize(res)

# %%
words_tokens
# Out:
# ['Hello',
#  'i',
#  'am',
#  'udaya',
#  'kumar',
#  '.',
#  'I',
#  'am',
#  'currenlty',
#  'doing',
#  'the',
#  'intership',
#  'at',
#  'Pyspiders',
#  'in',
#  'the',
#  'domain',
#  'of',
#  'Python',
#  'with',
#  'Data',
#  'Science',
#  '.',
#  'Located',
#  'BTM',
#  'layout',
#  '.']

# %%
sent_tokens=sent_tokenize(res)

# %%
sent_tokens
# Out:
# ['Hello i am udaya kumar\n.',
#  'I am currenlty doing the intership at Pyspiders in the domain of Python with Data Science.',
#  'Located BTM layout.']

# %%
res.split()
# Out:
# ['Hello',
#  'i',
#  'am',
#  'udaya',
#  'kumar',
#  '.',
#  'I',
#  'am',
#  'currenlty',
#  'doing',
#  'the',
#  'intership',
#  'at',
#  'Pyspiders',
#  'in',
#  'the',
#  'domain',
#  'of',
#  'Python',
#  'with',
#  'Data',
#  'Science.',
#  'Located',
#  'BTM',
#  'layout.']

# %%
res.split('.')
# Out:
# ['Hello i am udaya kumar\n',
#  ' \n      I am currenlty doing the intership at Pyspiders in the domain of Python with Data Science',
#  ' Located BTM layout',
#  '']

# %%
import re

# %%
# re.findall('\s',res) #returns single space
# re.findall(r'\s+',res) # + is used to group the patterns, if space is there and another space is present next to it then it groups
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  ' \n      ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ']

# %%
# re.findall(r'\s+',res)
re.sub(r'\s+','',res)
# Out:
# 'Helloiamudayakumar.IamcurrenltydoingtheintershipatPyspidersinthedomainofPythonwithDataScience.LocatedBTMlayout.'

# %%
re.sub(r'\s{2,}','',res)
# Out:
# 'Hello i am udaya kumar\n.I am currenlty doing the intership at Pyspiders in the domain of Python with Data Science. Located BTM layout.'
