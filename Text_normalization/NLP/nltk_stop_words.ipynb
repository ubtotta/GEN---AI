# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91789\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
stop_words=stopwords.words('english')

# %%
with open('data.txt') as file:
    data=file.read()

# %%
token=word_tokenize(data)

# %%
updated_tokens=[]
for word in token:
    if word not in stop_words:
        updated_tokens.append(word)
print(updated_tokens)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'resting', 'grass', '.']

# %% [markdown]
# - data + stop_words

# %%
# for word in stop_words:
#     if word in data:
#         data=data.replace(word,'')  #'T quck brwn fx j r  lz g n  ng n  gr.'
                                    #we can directly compare the words with data which is a string , because it checks character based

# %% [markdown]
# - sentance + stop_words

# %%
sent_token=sent_tokenize(data)

# %%
nltk_sentances='''The quick brown fox jumps over the lazy dog on a sunny day.
Artificial intelligence is changing the way that we live and work every day.
There is a large book on the wooden table in the living room.
She went to the grocery store to buy some fresh fruits for breakfast.
He was running as fast as he could to catch the last bus.
This is a very simple example that shows how NLTK removes stop words.
Which of these paths will lead us to the top of the mountain?
Learning a new programming language can be both fun and challenging for beginners. 
The movie was so interesting that I watched it twice in one week.
They are planning a trip to Paris because they want to see the Eiffel Tower.'''

# %%
sent_token=sent_tokenize(nltk_sentances)
sent_token
# Out:
# ['The quick brown fox jumps over the lazy dog on a sunny day.',
#  'Artificial intelligence is changing the way that we live and work every day.',
#  'There is a large book on the wooden table in the living room.',
#  'She went to the grocery store to buy some fresh fruits for breakfast.',
#  'He was running as fast as he could to catch the last bus.',
#  'This is a very simple example that shows how NLTK removes stop words.',
#  'Which of these paths will lead us to the top of the mountain?',
#  'Learning a new programming language can be both fun and challenging for beginners.',
#  'The movie was so interesting that I watched it twice in one week.',
#  'They are planning a trip to Paris because they want to see the Eiffel Tower.']

# %%
new_data=[]
for sent in sent_token:
    words=word_tokenize(sent)
    cleaned_words=[]
    for word in words:
        if word.lower() not in stop_words:
            cleaned_words.append(word)
    new_data.append(' '.join(cleaned_words))

# %%
new_data
# Out:
# ['quick brown fox jumps lazy dog sunny day .',
#  'Artificial intelligence changing way live work every day .',
#  'large book wooden table living room .',
#  'went grocery store buy fresh fruits breakfast .',
#  'running fast could catch last bus .',
#  'simple example shows NLTK removes stop words .',
#  'paths lead us top mountain ?',
#  'Learning new programming language fun challenging beginners .',
#  'movie interesting watched twice one week .',
#  'planning trip Paris want see Eiffel Tower .']

# %%
sentance=['Gen-AI is a part of AI', 'ML is a subset of AI']
for index in range(len(sentance)):
    words=sentance[index].split()
    filtered_words=[word for word in words if word not in stop_words]
    sentance[index]=' '.join(filtered_words)

# %%
sentance
# Out:
# ['Gen-AI part AI', 'ML subset AI']

# %% [markdown]
# ## word level tokenization + stopwords is the efficient way for removing the stopwords
