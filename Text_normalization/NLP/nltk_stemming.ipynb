# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
words = [
    "running", "jumps", "easily", "flying", "happiness",
    "played", "singing", "players", "creation", "creative",
    "studies", "studying", "connection", "connected", "connections",
    "running", "runner", "emojies", "dogs", "children","a", "and", "the"
]

for word in words:
    print(f'{word} ---> {stemmer.stem(word)}')
# Out:
# running ---> run
# jumps ---> jump
# easily ---> easili
# flying ---> fli
# happiness ---> happi
# played ---> play
# singing ---> sing
# players ---> player
# creation ---> creation
# creative ---> creativ
# studies ---> studi
# studying ---> studi
# connection ---> connect
# connected ---> connect
# connections ---> connect
# running ---> run
# runner ---> runner
# emojies ---> emoji
# dogs ---> dog
# children ---> children
# a ---> a
# and ---> and
# the ---> the

# %% [markdown]
# - this stemming works based on some rules
# - first converts all the chars to lower case
# - it just removes the suffix based on rule

# %%
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
stop_words=stopwords.words('english')
snowball_Stemmer=SnowballStemmer('english',ignore_stopwords=True)

# %%
snowball_words = [
    "running", "jumps", "easily", "flying", "happiness",
    "played", "singing", "players", "creation", "creative",
    "studies", "studying", "connection", "connected", "connections",
    "running", "runner", "emojies", "dogs", "children","a", "and", "the"
]

for word in snowball_words:
    print(f'{word} ---> {snowball_Stemmer.stem(word)}')
# Out:
# running ---> run
# jumps ---> jump
# easily ---> easili
# flying ---> fli
# happiness ---> happi
# played ---> play
# singing ---> sing
# players ---> player
# creation ---> creation
# creative ---> creativ
# studies ---> studi
# studying ---> studi
# connection ---> connect
# connected ---> connect
# connections ---> connect
# running ---> run
# runner ---> runner
# emojies ---> emoji
# dogs ---> dog
# children ---> children
# a ---> a
# and ---> and
# the ---> the

# %% [markdown]
# - ***porterstemmer*** : only english language, converts all chars to lower case, includes stopwords
# - ***snowballstemmer*** : supports many languages, keeps same case, excludes the stopwords

# %%
snowball_Stemmer.stopwords = stopwords
snowball_Stemmer.stemmer

# %%
for word in snowball_words:
    print(f'{word} ---> {snowball_Stemmer.stem(word)}')
# Out:
# running ---> run
# jumps ---> jump
# easily ---> easili
# flying ---> fli
# happiness ---> happi
# played ---> play
# singing ---> sing
# players ---> player
# creation ---> creation
# creative ---> creativ
# studies ---> studi
# studying ---> studi
# connection ---> connect
# connected ---> connect
# connections ---> connect
# running ---> run
# runner ---> runner
# emojies ---> emoji
# dogs ---> dog
# children ---> children
# a ---> a
# and ---> and
# the ---> the

# %% [markdown]
# - even after assigning the stop words also still the snownall_stemmer is not excluding the stopwords so we wont use this in real time scenarios
