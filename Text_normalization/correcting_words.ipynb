# %%
from textblob import TextBlob

# %%
s='corrting the wods for txt normalization'
text='corret the wods for txt normalization'

# %%
corrected_words=TextBlob(text).correct()
print(corrected_words,type(corrected_words))
# Out:
# correct the words for txt normalization <class 'textblob.blob.TextBlob'>
