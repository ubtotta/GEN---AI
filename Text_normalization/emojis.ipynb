# %%
import emoji

# %%
s='Helloooooo 👍✌️'
emoji.replace_emoji(s,'')
# Out:
# 'Helloooooo '

# %%
s='Helloooooo ✌️❤️💕😘😒😍😉🤞😜😂'
emoji.replace_emoji(s,'')
emoji.demojize(s)
# Out:
# 'Helloooooo :victory_hand::red_heart::two_hearts::face_blowing_a_kiss::unamused_face::smiling_face_with_heart-eyes::winking_face::crossed_fingers::winking_face_with_tongue::face_with_tears_of_joy:'
