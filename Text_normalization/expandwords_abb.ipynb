# %%
import contractions

# %%
s1="I'm not Okay"
s2="btw ASAP I'll try to complete the task"
print(contractions.fix(s1))
print(contractions.fix(s2))
# Out:
# I am not Okay
# by the way AS SOON AS POSSIBLE I will try to complete the task
